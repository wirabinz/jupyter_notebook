# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Import Data from Real Testing

# %%
df = pd.read_csv('saatcioglu1989u4.csv')
df.head()
# Out:
#         x        y
# 0  0.0000  0.00000
# 1  0.0967  0.06983
# 2  0.1040  0.09232
# 3  0.1040  0.33740
# 4  0.0933  0.99410

# %%
x=df['x']
y=df['y']
plt.plot(x,y)
